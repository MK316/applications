# %% [markdown]
# <a href="https://colab.research.google.com/github/MK316/applications/blob/main/LDA_topic_modelling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install bertopic
# Out:
# ...
#      |████████████████████████████████| 58 kB 3.5 MB/s
# ...
#      |████████████████████████████████| 79 kB 7.4 MB/s
# ...
#      |████████████████████████████████| 5.2 MB 56.2 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 88 kB 6.3 MB/s
# ...
#      |████████████████████████████████| 4.2 MB 44.3 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 50.0 MB/s
# ...
#      |████████████████████████████████| 84 kB 3.0 MB/s
# ...
#      |████████████████████████████████| 636 kB 64.9 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 36.0 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 50.6 MB/s
# ...
#   Created wheel for hdbscan: filename=hdbscan-0.8.28-cp37-cp37m-linux_x86_64.whl size=2330832 sha256=ea97bb131c109a4884ad702d75cb5355455fca9835e80a4ad2ee2a2fb42f394d
#   Stored in directory: /root/.cache/pip/wheels/6e/7a/5e/259ccc841c085fc41b99ef4a71e896b62f5161f2bc8a14c97a
# ...

# %%
from bertopic import BERTopic
topic_model = BERTopic()

# %% [markdown]
# We have imported the “fetch_20newsgroups” dataset from SKLearn.datasets module. “fetch_20newsgroups” dataset includes news articles and news-related materials.

# %%
from sklearn.datasets import fetch_20newsgroups

# %%
docs = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))['data']

# %%
topics, _ = topic_model.fit_transform(docs)
# Out:
# /usr/local/lib/python3.7/dist-packages/numba/np/ufunc/parallel.py:363: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#   warnings.warn(problem)

# %%
topic_model.get_topic_info()
# Out:
#      Topic  Count                                     Name
# 0       -1   6486                         -1_to_the_and_is
# 1        0   1827                     0_game_team_games_he
# 2        1    591            1_key_clipper_chip_encryption
# 3        2    531                2_idjits_ites_hello_cheek
# 4        3    495               3_israel_israeli_jews_arab
# ..     ...    ...                                      ...
# 207    206     10             206_koresh_sda_shephards_rod
# 208    207     10            207_rights_sky_right_trespass
# 209    208     10                208_law_jesus_sabbath_god
# 210    209     10   209_barrel_condensers_shipping_dollars
# 211    210     10  210_potassium_arrhythmias_cardiac_heart
#
# [212 rows x 3 columns]

# %%
topic_model.get_topic(49)
# Out:
# [('paint', 0.036858153391272616),
#  ('wax', 0.03347666212005165),
#  ('plastic', 0.026997713725866145),
#  ('scratches', 0.017555896633802935),
#  ('finish', 0.015071366103809514),
#  ('acetone', 0.014734701931156474),
#  ('car', 0.014374370392903147),
#  ('solvent', 0.01394285490908835),
#  ('stuff', 0.012729224654683971),
#  ('polish', 0.012028697020603977)]

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
