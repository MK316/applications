# %% [markdown]
# <a href="https://colab.research.google.com/github/MK316/applications/blob/main/names1000_2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Popular names and creating sample data

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/MK316/data/main/names1000.csv"
f = pd.read_csv(url)
print(data.head())
f.tail()
# Out:
#     Names
# 0    Liam
# 1    Noah
# 2  Oliver
# 3  Elijah
# 4   James
#        Names
# 995   Heaven
# 996     Kyla
# 997  Wrenley
# 998   Meadow
# 999   Carter

# %%
# Add [gender] column

import numpy as np

x = np.array(["Male", "Female"])
y = np.repeat(x, [500, 500], axis=0)

f['Gender'] = y
f.head()
# Out:
#     Names Gender
# 0    Liam   Male
# 1    Noah   Male
# 2  Oliver   Male
# 3  Elijah   Male
# 4   James   Male

# %%
data = f.sample(100)
data.head()
# Out:
#          Names  Gender
# 937     Astrid  Female
# 605      Maria  Female
# 987  Charleigh  Female
# 623      Maeve  Female
# 874      Mabel  Female

# %% [markdown]
# ## Creating random data with {Numpy} package

# %% [markdown]
# *Goal: create random grades of 3 subjects (English, Korean, Math)

# %%
import numpy as np

# %%
set1 = np.random.normal(50, 30, 10000)

grade = []
for n in range(0, len(set1)):
  g = round(set1[n],1)
  if 30 < set1[n] < 101:
    grade.append(g)
    if len(grade) < 100:
      n = n+1
    elif len(grade) == 100:
      break

grade[:10]
# Out:
# [48.4, 36.7, 85.3, 87.9, 55.7, 65.8, 32.2, 86.8, 61.9, 87.6]

# %%
data1 = f.sample(100)
data1.head()
# Out:
#          Names  Gender
# 12   Alexander    Male
# 594   Madeline  Female
# 663    Ryleigh  Female
# 934      Ariah  Female
# 17       Mason    Male

# %%
#@markdown Create dataframe with random grades for a subject: 

#@markdown Todo: Write the name of the subject in a popup window. (e.g., Korean, English, Math)
set1 = np.random.normal(50, 30, 10000)

grade = []
for n in range(0, len(set1)):
  g = round(set1[n],1)
  if 30 < set1[n] < 101:
    grade.append(g)
    if len(grade) < 100:
      n = n+1
    elif len(grade) == 100:
      break

grade[:10]

text = input()
subject = str(text)
data1[subject] = grade
data1.head()
# Out:
# Music
#          Names  Gender  Music
# 12   Alexander    Male   39.4
# 594   Madeline  Female   53.1
# 663    Ryleigh  Female   46.6
# 934      Ariah  Female   66.1
# 17       Mason    Male   93.8

# %%
data2 = data1
data2.head()
# Out:
#          Names  Gender  Music
# 12   Alexander    Male   39.4
# 594   Madeline  Female   53.1
# 663    Ryleigh  Female   46.6
# 934      Ariah  Female   66.1
# 17       Mason    Male   93.8

# %% [markdown]
# ## Plots using {matplotlib}
#
# [matplotlib manual](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html)

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(grade)
# Out:
# (array([12., 12., 14., 10., 19., 11., 12.,  3.,  1.,  6.]),
#  array([33.3 , 39.93, 46.56, 53.19, 59.82, 66.45, 73.08, 79.71, 86.34,
#         92.97, 99.6 ]),
#  <a list of 10 Patch objects>)
