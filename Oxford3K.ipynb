# %% [markdown]
# <a href="https://colab.research.google.com/github/MK316/applications/blob/main/Oxford3K.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🌀**Step1: Reading data (Oxford Learners' vocabulary 3K)**

# %%
#@markdown 🔳 Data: Oxford learner's vocabulary 3K: df, show first 5, last 5 words
import pandas as pd

url = "https://raw.githubusercontent.com/MK316/workshop22/main/data/oxford3k.csv"

df = pd.read_csv(url)
print(df.head())
print(df.tail())
# Out:
#   ID WORD
# 0  1  the
# 1  2   of
# 2  3   be
# 3  4  and
# 4  5    a
#         ID       WORD
# 2995  2996     dinner
# 2996  2997  developed
# 2997  2998   collapse
# 2998  2999      short
# 2999  3000    essence

# %% [markdown]
# # 🌀**Step 2: Set up TTS**

# %%
#@markdown 🚩 {gTTS} package installation and import
# %%capture
# !pip install gTTS
from gtts import gTTS
from IPython.display import Audio

# %%
#@markdown 🚩 Getting ready to use { tts ( _text_to_say_) }:
def tts(mytext):

#Install gTTS
# !pip install gTTS
# from gtts import gTTS
# from IPython.display import Audio

  text_to_say = mytext

# Step ⓵ Language to choose:
  language_to_choose = "en" #@param ["en", "fr","ko",'es']
  Slow_speed = "False" #@param ["True","False"]
  # lang = language_to_choose

  print("Play language accent: %s"%language_to_choose)
  language = language_to_choose

# gTTS
  gtts_object = gTTS(text = text_to_say,
                     lang = language,
                    slow = Slow_speed)
  
# #@markdown Step ③: Create the audio file (.wav) to play:
  gtts_object.save("mytext.wav")

# # Output
  return Audio("mytext.wav")

# %% [markdown]
# # 🌀**Step 3: Creating audio files**
#
# **Write two numbers to indicate the range:**
#
# e.g., If you want words from 150 to 200, write 150,200(More words take longer time. For example, 100 words will yield approximately 2 mins' audio, and it takes 15 seconds to create the audio file.)

# %%
#@markdown 📌 Write two numbers (start, end): (1, 3000)

#@markdown => e.g., If you want words from 1st to the 50th, write 1,50
print('Write the start number')
voca_range = input()
vrange = voca_range.split(",")
nx = int(vrange[0])
ny = int(vrange[1])

windex = list(df['ID'])
wlist = list(df['WORD'])

myindex = windex[nx:ny]
mywords = wlist[nx:ny]
text_to_say = "Let's get started! " + '! '.join(mywords) + ". " + "This is the end."

print(mywords)
tts(text_to_say)
# Out:
# Write the start number
# 100,200
# ['become', 'any', 'life', 'most', 'even', 'her', 'provide', 'get', 'however', 'each', 'give', 'know', 'come', 'while', 'like', 'during', 'research', 'teacher', 'problem', 'education', 'as', 'American', 'level', 'now', 'work', 'just', 'man', 'need', 'over', 'case', 'political', 'number', 'three', 'community', 'in', 'own', 'after', 'result', 'show', 'government', 'same', 'work', 'large', 'include', 'such', 'day', 'must', 'among', 'great', 'area', 'country', 'most', 'important', 'family', 'different', 'process', 'power', 'part', 'national', 'use', 'service', 'within', 'development', 'data', 'think', 'often', 'information', 'question', 'very', 'issue', 'another', 'effect', 'call', 'health', 'might', 'begin', 'us', 'change', 'table', 'policy', 'help', 'although', 'university', 'both', 'model', 'small', 'company', 'experience', 'good', 'me', 'activity', 'human', 'member', 'still', 'him', 'history', 'want', 'without', 'create', 'develop']
# Play language accent: en
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
